# %% [markdown]
# <a href="https://colab.research.google.com/github/Safhanafarha775/Weather-Data-Dashboard/blob/main/Weather-Data-Dashboard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #🌦 Weather Data Dashboard

# %% [markdown]
# ###Step 1: Install & Import Libraries

# %%
import requests
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ###Step 2: Fetch Weather Data

# %%
import requests

API_KEY = "f152895c910d3f1fff7c7b4e89798615"
city = "London"
url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={API_KEY}&units=metric"
response = requests.get(url).json()

print(response)
# Out:
# {'coord': {'lon': -0.1257, 'lat': 51.5085}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 16.99, 'feels_like': 16.76, 'temp_min': 16.99, 'temp_max': 16.99, 'pressure': 1003, 'humidity': 77, 'sea_level': 1003, 'grnd_level': 1000}, 'visibility': 10000, 'wind': {'speed': 5.56, 'deg': 182, 'gust': 8.25}, 'rain': {'1h': 0.27}, 'clouds': {'all': 77}, 'dt': 1756808089, 'sys': {'country': 'GB', 'sunrise': 1756790098, 'sunset': 1756838749}, 'timezone': 3600, 'id': 2643743, 'name': 'London', 'cod': 200}

# %%
API_KEY = "24cc05c4b1fad7365147bfd16ab43380"
cities = ["London", "New York", "Dubai", "Mumbai", "Tokyo"]

weather_data=[]

for city in cities:
  url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={API_KEY}&units=metric"
  response = requests.get(url).json()

  data = {
        "City": city,
        "Temperature (°C)": response["main"]["temp"],
        "Humidity (%)": response["main"]["humidity"],
        "Wind Speed (m/s)": response["wind"]["speed"]
    }
  weather_data.append(data)

df = pd.DataFrame(weather_data)
print(df)
# Out:
#        City  Temperature (°C)  Humidity (%)  Wind Speed (m/s)
# 0    London             16.99            77              5.56
# 1  New York             15.23            84              2.89
# 2     Dubai             36.60            50              4.31
# 3    Mumbai             27.64            81              6.39
# 4     Tokyo             31.86            53              8.19

# %% [markdown]
# ###Step 2 : Visualise Data

# %%
# Temperature comparison
sns.barplot(x="City", y="Temperature (°C)", data=df)
plt.title("Temperature Comparison Across Cities")
plt.show()

# %%
# Humidity trend
sns.lineplot(x="City", y="Humidity (%)", data=df, marker="o")
plt.title("Humidity Levels in Cities")
plt.show()

# %% [markdown]
# ###Step 4 : Save Data

# %%
df.to_csv("weather_data.csv", index=False)
